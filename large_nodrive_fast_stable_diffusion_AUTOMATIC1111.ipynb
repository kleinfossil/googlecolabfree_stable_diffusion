# %% [markdown]
# <a href="https://colab.research.google.com/github/kleinfossil/googlecolabfree_stable_diffusion/blob/main/large_nodrive_fast_stable_diffusion_AUTOMATIC1111.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook From https://github.com/TheLastBen/fast-stable-diffusion, if you encounter any issues, feel free to discuss them.** [Support](https://ko-fi.com/thelastben)
#
# I adjusted the Notebook to work without drive

# %%
import os

#@markdown #Use Drive
Use_Drive = False #@param {type:"boolean"}
#@markdown Using drive will make the installation persistent, but will also consume space on your google drive.

if Use_Drive:
  from google.colab import drive
  local_folder = '/content/gdrive'
  drive.mount(local_folder)
else:
  local_folder = '/content'

# %env LOCAL_FOLDER=$local_folder
# Out:
# env: LOCAL_FOLDER=/content

# %%
#@markdown # Install/Update AUTOMATIC1111 repo
from IPython.utils import capture
from IPython.display import clear_output
from subprocess import getoutput
import ipywidgets as widgets
import sys
import fileinput
import os
import time

if Use_Drive:
  if not os.path.exists("/content/gdrive/MyDrive/"):
    print('[1;31mGdrive not connected, using colab storage ...')
    time.sleep(4)
    # !mkdir -p /content/gdrive/MyDrive/
  else:
    print("Already Connected")
else:
  print("Use non-persistent storage")

with capture.capture_output() as cap:
  def inf(msg, style, wdth): inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)
  fgitclone = "git clone --depth 1"
  os.makedirs(f"{local_folder}/sd", exist_ok=True)
  os.chdir(f"{local_folder}/sd")
  # !$fgitclone -q --branch master https://github.com/AUTOMATIC1111/stable-diffusion-webui
  # !mkdir -p "${LOCAL_FOLDER}/sd/stable-diffusion-webui/cache/huggingface"
  # !ln -s "${LOCAL_FOLDER}/sd/stable-diffusion-webui/cache/huggingface /root/.cache/"
print(cap)

with capture.capture_output() as cap:
  os.chdir(f"{local_folder}/sd/stable-diffusion-webui/")
  # !git reset --hard
  time.sleep(1)
  # !rm webui.sh
print(cap)
print('[1;32m')
# !git pull
clear_output()
inf('\u2714 Done','success', '50px')
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %%
#@markdown # Requirements

print('[1;32mInstalling requirements...')

with capture.capture_output() as cap:
  # %cd /content/ 
  # !wget -q -i https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/Dependencies/A1111.txt
  # !dpkg -i *.deb
  if not os.path.exists(f"{os.getenv('LOCAL_FOLDER')}/sd/stablediffusion"):
    # !tar -C / --zstd -xf sd.tar.zst 
  # !tar -C / --zstd -xf gcolabdeps.tar.zst
  # !rm *.deb | rm *.zst | rm *.txt
  # %env LD_PRELOAD=libtcmalloc.so
  os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
print(cap)

clear_output()
inf('\u2714 Done','success', '50px')
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %%
#@markdown # Model Download/Load
Model_Version = "1.5" #@param [ "1.5", "v1.5 Inpainting ", "V2.1-512px", "V2.1-768px"]

Redownload_the_original_model = True #@param {type:"boolean"}

def rmv():
  # !wget -q -O "${LOCAL_FOLDER}/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/precompiled/README.md"
  # !mv "${LOCAL_FOLDER}/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt ${LOCAL_FOLDER}/sd/stable-diffusion-webui/models/Stable-diffusion/trashfile.f"
  time.sleep(2)
  # !rm "${LOCAL_FOLDER}/sd/stable-diffusion-webui/models/Stable-diffusion/trashfile.f"
  clear_output()

if Redownload_the_original_model:
  with capture.capture_output() as cap:
    rmv()

#@markdown Or
Path_to_MODEL = "" #@param {type:"string"}
#@markdown - Insert the full path of your trained model or to a folder containing multiple models.

#@markdown Or
MODEL_LINK = "" #@param {type:"string"}
safetensors = False #@param {type:"boolean"}
Use_temp_storage = False #@param {type:"boolean"}



def newmdl():

    if not os.path.exists(f"{os.getenv('LOCAL_FOLDER')}/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt"):
      # %cd /content/
      clear_output()
      # !git init
      # !git lfs install --system --skip-repo
      # !$fgitclone --branch fp16 "https://huggingface.co/runwayml/stable-diffusion-v1-5"
      if os.path.exists('/content/stable-diffusion-v1-5/unet/diffusion_pytorch_model.bin'):
        # !wget -q -O stable-diffusion-v1-5/vae/diffusion_pytorch_model.bin https://huggingface.co/stabilityai/sd-vae-ft-mse/resolve/main/diffusion_pytorch_model.bin
        # !wget -O convertosd.py https://github.com/TheLastBen/fast-stable-diffusion/raw/main/Dreambooth/convertosd.py
        # !sed -i '201s@.*@    model_path = "/content/stable-diffusion-v1-5"@' /content/convertosd.py
        # !sed -i '202s@.*@    checkpoint_path= "'${LOCAL_FOLDER}'/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt"@' /content/convertosd.py
        clear_output()       
        # !python /content/convertosd.py
        # !rm /content/convertosd.py
        if os.path.exists(f"{os.getenv('LOCAL_FOLDER')}/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt"):
          model=f"{os.getenv('LOCAL_FOLDER')}/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt"
          clear_output()
          inf('\u2714 Done','success', '50px')
        else:
          inf('\u2718 Something went wrong, try again','danger', "250px")
      else:
        inf('\u2718 Something went wrong','danger', "200px")

    else:
      model=f"{os.getenv('LOCAL_FOLDER')}/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt"
      clear_output()
      inf('\u2714 Model already exists, check the box "Redownload_the_original_model" to redownload/download the V1.5','primary', '700px')

    if os.path.exists('/content/.git'):
      # !rm -r /content/.git

    if os.path.exists('/content/stable-diffusion-v1-5'):
      # !rm -r /content/stable-diffusion-v1-5

    return model

def V2():

    if not os.path.exists(f"{os.getenv('LOCAL_FOLDER')}/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt"):
      # %cd /content/
      clear_output()
      # !mkdir "/content/stable-diffusion-V2"
      # %cd "/content/stable-diffusion-V2"
      # !git init
      # !git lfs install --system --skip-repo
      if Model_Version == "V2.1-768px":
        # !git remote add -f origin  "https://huggingface.co/stabilityai/stable-diffusion-2-1"
      elif Model_Version == "V2.1-512px":
        # !git remote add -f origin  "https://huggingface.co/stabilityai/stable-diffusion-2-1-base"
      # !git config core.sparsecheckout true
      # !echo -e "scheduler\ntext_encoder\ntokenizer\nunet\nvae\nfeature_extractor\nmodel_index.json\n!*.safetensors" > .git/info/sparse-checkout
      # !git pull origin fp16
      # %cd /content
      # !wget -O convertosdv2.py https://github.com/TheLastBen/fast-stable-diffusion/raw/main/Dreambooth/convertosdv2.py
      clear_output()
      # !python /content/convertosdv2.py --fp16 /content/stable-diffusion-V2 "${LOCAL_FOLDER}/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt"
      # !rm /content/convertosdv2.py
      if os.path.exists(f"{os.getenv('LOCAL_FOLDER')}/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt"):
        model=f"{os.getenv('LOCAL_FOLDER')}/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt"
        clear_output()
        inf('\u2714 Done','success', '50px')
      else:
        inf('\u2718 Something went wrong, try again','danger', "250px")

    else:
      model=f"{os.getenv('LOCAL_FOLDER')}/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt"
      clear_output()
      inf('\u2714 Model already exists, check the box "Redownload_the_original_model" to redownload/download the V2','primary', '700px')

    if os.path.exists('/content/.git'):
      # !rm -r /content/.git
      # !rm -r /content/convertosdv2.py
    if os.path.exists('/content/stable-diffusion-V2'):
      # !rm -r /content/stable-diffusion-V2

    return model

def inpmdl():

    if not os.path.exists(f"{os.getenv('LOCAL_FOLDER')}/sd/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.ckpt"):
      # %cd /content/
      clear_output()
      # !git init
      # !git lfs install --system --skip-repo
      # !$fgitclone --branch fp16 "https://huggingface.co/runwayml/stable-diffusion-inpainting"
      if os.path.exists('/content/stable-diffusion-inpainting'):
        # !$fgitclone "https://huggingface.co/stabilityai/sd-vae-ft-mse"
        # !rm -r /content/stable-diffusion-inpainting/vae
        # !mv /content/sd-vae-ft-mse /content/stable-diffusion-inpainting/vae        
        # !wget -O convertosd.py https://github.com/TheLastBen/fast-stable-diffusion/raw/main/Dreambooth/convertosd.py
        # !sed -i '201s@.*@    model_path = "/content/stable-diffusion-inpainting"@' /content/convertosd.py
        # !sed -i '202s@.*@    checkpoint_path= "'${LOCAL_FOLDER}'/sd/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.ckpt"@' /content/convertosd.py
        clear_output()       
        # !python /content/convertosd.py
        # !rm /content/convertosd.py
        if os.path.exists(f"{os.getenv('LOCAL_FOLDER')}/sd/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.ckpt"):
          model=f"{os.getenv('LOCAL_FOLDER')}/sd/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.ckpt"
          clear_output()
          inf('\u2714 Done','success', '50px')
        else:
          inf('\u2718 Something went wrong, try again','danger', "250px")
      else:
        inf('\u2718 Something went wrong','danger', "200px")


    else:
      model=f"{os.getenv('LOCAL_FOLDER')}/sd/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.ckpt"
      clear_output()
      inf('\u2714 inpainting model already exists','primary', '250px')

    if os.path.exists('/content/.git'):
      # !rm -r /content/.git

    if os.path.exists('/content/stable-diffusion-inpainting'):
      # !rm -r /content/stable-diffusion-inpainting

    return model

if (Path_to_MODEL !=''):
  if os.path.exists(str(Path_to_MODEL)):
    inf('\u2714 Using the trained model.','success', '200px')

  else:
      while not os.path.exists(str(Path_to_MODEL)):
        inf('\u2718 Wrong path, use the colab file explorer to copy the path : ','danger', "400px")
        Path_to_MODEL=input()
      if os.path.exists(str(Path_to_MODEL)):
        inf('\u2714 Using the trained model.','success', '200px')

  model=Path_to_MODEL

elif MODEL_LINK != "":
  gdrv=f"{os.getenv('LOCAL_FOLDER')}/sd/stable-diffusion-webui/models/Stable-diffusion"
  tmp="/content"
  pth=tmp if Use_temp_storage else gdrv
  # %cd $pth
  clear_output()
  if not safetensors:
    modelname="model.ckpt"
  else:
    modelname="model.safetensors"
  # !gdown --fuzzy -O $modelname $MODEL_LINK
  if os.path.exists(f'{pth}/{modelname}') and os.path.getsize(f'{pth}/{modelname}') > 1810671599:    
      model=f'{pth}/{modelname}'
      clear_output()
      inf('\u2714 Model downloaded, using the trained model.','success', '350px')
  else:
    if Use_temp_storage:
      # !rm $pth/$modelname
    else:
      rmv()
    inf('\u2718 Wrong link, check that the link is valid','danger', "300px")


elif Model_Version=="1.5":
  model=newmdl()

elif Model_Version=="V2.1-512px" or Model_Version=="V2.1-768px":
  model=V2()

else:
   model=inpmdl()
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %%
#@markdown # ControlNet
from torch.hub import download_url_to_file
from urllib.parse import urlparse
import re

Model = "Canny" #@param [ "All", "Canny", "Depth", "HED", "MLSD", "Normal", "OpenPose", "Scribble", "Seg", "T2iadapter_Models"]

#@markdown - Download/update ControlNet extension and its models.

def download(url, model_dir):

    filename = os.path.basename(urlparse(url).path)
    pth = os.path.abspath(os.path.join(model_dir, filename))
    if not os.path.exists(pth):
        print('Downloading: '+os.path.basename(url))
        download_url_to_file(url, pth, hash_prefix=None, progress=True)
    else:
      print(f"[1;32mThe model {filename} already exists[0m")

Canny='https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_canny-fp16.safetensors'
Depth='https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_depth-fp16.safetensors'
HED='https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_hed-fp16.safetensors'
MLSD='https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_mlsd-fp16.safetensors'
Normal='https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_normal-fp16.safetensors'
OpenPose='https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_openpose-fp16.safetensors'
Scribble='https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_scribble-fp16.safetensors'
Seg='https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_seg-fp16.safetensors'


with capture.capture_output() as cap:
  os.chdir(f"{local_folder}/sd/stable-diffusion-webui/extensions")
  if not os.path.exists("sd-webui-controlnet"):
    # !git clone https://github.com/Mikubill/sd-webui-controlnet.git
    # %cd /content
  else:
    # %cd sd-webui-controlnet
    # !git reset --hard
    # !git pull
    # %cd /content

mdldir=f"{os.getenv('LOCAL_FOLDER')}/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
for filename in os.listdir(mdldir):
  if "_sd14v1" in filename:
    renamed = re.sub("_sd14v1", "-fp16", filename)
    os.rename(os.path.join(mdldir, filename), os.path.join(mdldir, renamed))

# !wget -q -O CN_models.txt https://github.com/TheLastBen/fast-stable-diffusion/raw/main/AUTOMATIC1111_files/CN_models.txt
with open("CN_models.txt", 'r') as f:
  mdllnk = f.read().splitlines()
# !rm CN_models.txt

if Model == "All": 
  for lnk in mdllnk:
      download(lnk, mdldir)
  clear_output()
  inf('\u2714 Done','success', '50px')

elif Model == "T2iadapter_Models":
  mdllnk=list(filter(lambda x: 't2i' in x, mdllnk))
  for lnk in mdllnk:
      download(lnk, mdldir)
  clear_output()
  inf('\u2714 Done','success', '50px')

else:
  download(globals()[Model], mdldir)
  clear_output()
  inf('\u2714 Done','success', '50px')
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %%
#@markdown # Start Stable-Diffusion
from IPython.utils import capture
import time
import sys
import fileinput

Use_localtunnel = True #@param {type:"boolean"}

User = "" #@param {type:"string"}
Password= "" #@param {type:"string"}
#@markdown - Add credentials to your Gradio interface (optional).

auth=f"--gradio-auth {User}:{Password}"
if User =="" or Password=="":
  auth=""

with capture.capture_output() as cap:
  if not os.path.exists('/tools/node/bin/lt'):
    # !npm install -g localtunnel

with capture.capture_output() as cap:
  os.chdir(f"{local_folder}/sd/stable-diffusion-webui/modules/")
  # !wget -O paths.py https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/AUTOMATIC1111_files/paths.py
  # !wget -O extras.py https://raw.githubusercontent.com/AUTOMATIC1111/stable-diffusion-webui/master/modules/extras.py
  # !wget -O sd_models.py https://raw.githubusercontent.com/AUTOMATIC1111/stable-diffusion-webui/master/modules/sd_models.py
  # !wget -q -O /usr/local/lib/python3.9/dist-packages/gradio/blocks.py https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/AUTOMATIC1111_files/blocks.py
  os.chdir(f"{local_folder}/sd/stable-diffusion-webui/")

  # !sed -i "s@os.path.splitext(checkpoint_file)@os.path.splitext(checkpoint_file); map_location='cuda'@" "'${LOCAL_FOLDER}'/sd/stable-diffusion-webui/modules/sd_models.py"
  # !sed -i 's@ui.create_ui().*@ui.create_ui();shared.demo.queue(concurrency_count=999999,status_update_rate=0.1)@' "'${LOCAL_FOLDER}'/sd/stable-diffusion-webui/webui.py"
  # !sed -i "s@map_location='cpu'@map_location='cuda'@" "${LOCAL_FOLDER}/sd/stable-diffusion-webui/modules/extras.py"

share=''
if not Use_localtunnel:
  share='--share'

else:
  with capture.capture_output() as cap:
    share=''
    # %cd /content
    # !nohup lt --port 7860 > srv.txt 2>&1 &
    time.sleep(2)
    # !grep -o 'https[^ ]*' /content/srv.txt >srvr.txt
    time.sleep(2)
    srv= getoutput('cat /content/srvr.txt')

    for line in fileinput.input('/usr/local/lib/python3.9/dist-packages/gradio/blocks.py', inplace=True):
      if line.strip().startswith('self.server_name ='):
          line = f'            self.server_name = "{srv[8:]}"\n'
      if line.strip().startswith('self.protocol = "https"'):
          line = '            self.protocol = "https"\n'
      if line.strip().startswith('if self.local_url.startswith("https") or self.is_colab'):
          line = ''
      if line.strip().startswith('else "http"'):
          line = ''
      sys.stdout.write(line)
            
    # !rm /content/srv.txt /content/srvr.txt
    os.chdir(f"{local_folder}/sd/stable-diffusion-webui/")

try:
  model
  if os.path.isfile(model):
    # !python "${LOCAL_FOLDER}/sd/stable-diffusion-webui/webui.py" $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae  --ckpt "$model" --xformers $auth --disable-console-progressbars
  else:
    # !python "${LOCAL_FOLDER}/sd/stable-diffusion-webui/webui.py" $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae  --ckpt-dir "$model" --xformers $auth --disable-console-progressbars
except:
   # !python "${LOCAL_FOLDER}/sd/stable-diffusion-webui/webui.py" $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae --xformers $auth --disable-console-progressbars
# Out:
# Checkpoint in --ckpt argument not found (Possible it was moved to /content/sd/stable-diffusion-webui/models/Stable-diffusion:
# Loading weights [4c86efd062] from /content/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt
# Creating model from config: /content/sd/stable-diffusion-webui/configs/v1-inference.yaml
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# Applying xformers cross attention optimization.
# Textual inversion embeddings loaded(0):
# Model loaded in 16.5s (load weights from disk: 3.5s, create model: 1.1s, apply weights to model: 2.7s, apply half(): 1.0s, load VAE: 7.3s, move model to device: 0.8s).
# Running on local URL: https://famous-ads-obey-34-142-208-3.loca.lt
# ✔ Connected
# Startup time: 27.7s (import torch: 5.7s, import gradio: 0.9s, import ldm: 0.3s, other imports: 1.6s, load scripts: 1.5s, load SD checkpoint: 16.6s, create ui: 0.9s, scripts app_started_callback: 0.1s).
# Interrupted with signal 2 in <frame at 0x170b4e010, file '/content/sd/stable-diffusion-webui/webui.py', line 209, code wait_on_server>

# %%
#@markdown # Start Stable-Diffusion SUB PROCESS
from IPython.utils import capture
import time
import sys
import fileinput
import subprocess

Use_localtunnel = False #@param {type:"boolean"}

User = "" #@param {type:"string"}
Password= "" #@param {type:"string"}
#@markdown - Add credentials to your Gradio interface (optional).

auth=f"--gradio-auth {User}:{Password}"
if User =="" or Password=="":
  auth=""

with capture.capture_output() as cap:
  if not os.path.exists('/tools/node/bin/lt'):
    # !npm install -g localtunnel

with capture.capture_output() as cap:
  os.chdir(f"{local_folder}/sd/stable-diffusion-webui/modules/")
  # !wget -O paths.py https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/AUTOMATIC1111_files/paths.py
  # !wget -O extras.py https://raw.githubusercontent.com/AUTOMATIC1111/stable-diffusion-webui/master/modules/extras.py
  # !wget -O sd_models.py https://raw.githubusercontent.com/AUTOMATIC1111/stable-diffusion-webui/master/modules/sd_models.py
  # !wget -q -O /usr/local/lib/python3.9/dist-packages/gradio/blocks.py https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/AUTOMATIC1111_files/blocks.py
  os.chdir(f"{local_folder}/sd/stable-diffusion-webui/")

  # !sed -i "s@os.path.splitext(checkpoint_file)@os.path.splitext(checkpoint_file); map_location='cuda'@" "'${LOCAL_FOLDER}'/sd/stable-diffusion-webui/modules/sd_models.py"
  # !sed -i 's@ui.create_ui().*@ui.create_ui();shared.demo.queue(concurrency_count=999999,status_update_rate=0.1)@' "'${LOCAL_FOLDER}'/sd/stable-diffusion-webui/webui.py"
  # !sed -i "s@map_location='cpu'@map_location='cuda'@" "${LOCAL_FOLDER}/sd/stable-diffusion-webui/modules/extras.py"

share=''
if not Use_localtunnel:
  share='--share'

else:
  with capture.capture_output() as cap:
    share=''
    # %cd /content
    # !nohup lt --port 7860 > srv.txt 2>&1 &
    time.sleep(2)
    # !grep -o 'https[^ ]*' /content/srv.txt >srvr.txt
    time.sleep(2)
    srv= getoutput('cat /content/srvr.txt')

    for line in fileinput.input('/usr/local/lib/python3.9/dist-packages/gradio/blocks.py', inplace=True):
      if line.strip().startswith('self.server_name ='):
          line = f'            self.server_name = "{srv[8:]}"\n'
      if line.strip().startswith('self.protocol = "https"'):
          line = '            self.protocol = "https"\n'
      if line.strip().startswith('if self.local_url.startswith("https") or self.is_colab'):
          line = ''
      if line.strip().startswith('else "http"'):
          line = ''
      sys.stdout.write(line)
            
    # !rm /content/srv.txt /content/srvr.txt
    os.chdir(f"{local_folder}/sd/stable-diffusion-webui/")

try:
  model
  if os.path.isfile(model):
    subprocess.Popen(["python", f"{local_folder}/sd/stable-diffusion-webui/webui.py", share,  "--api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae  --ckpt "$model" --xformers $auth --disable-console-progressbars
  else:
    # !python "${LOCAL_FOLDER}/sd/stable-diffusion-webui/webui.py" $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae  --ckpt-dir "$model" --xformers $auth --disable-console-progressbars
except:
   # !python "${LOCAL_FOLDER}/sd/stable-diffusion-webui/webui.py" $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae --xformers $auth --disable-console-progressbars

# %%
# !curl https://127.0.0.1
# Out:
# curl: (7) Failed to connect to 127.0.0.1 port 443: Connection refused

# %%
# !zip -r sd.zip /content/sd
# Out:
# 	zip warning: name not matched: /content/sd/.cache
#   adding: content/sd/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/localizations/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/localizations/Put localization files here.txt (stored 0%)
#   adding: content/sd/stable-diffusion-webui/modules/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/modules/gfpgan_model.py (deflated 70%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_samplers.py (deflated 63%)
#   adding: content/sd/stable-diffusion-webui/modules/sub_quadratic_attention.py (deflated 69%)
#   adding: content/sd/stable-diffusion-webui/modules/progress.py (deflated 68%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_hijack.py (deflated 76%)
#   adding: content/sd/stable-diffusion-webui/modules/ui_extra_networks_hypernets.py (deflated 59%)
#   adding: content/sd/stable-diffusion-webui/modules/script_loading.py (deflated 61%)
#   adding: content/sd/stable-diffusion-webui/modules/ui_tempdir.py (deflated 65%)
#   adding: content/sd/stable-diffusion-webui/modules/generation_parameters_copypaste.py (deflated 70%)
#   adding: content/sd/stable-diffusion-webui/modules/extra_networks_hypernet.py (deflated 63%)
#   adding: content/sd/stable-diffusion-webui/modules/scripts.py (deflated 78%)
#   adding: content/sd/stable-diffusion-webui/modules/call_queue.py (deflated 65%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_samplers_common.py (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/modules/upscaler.py (deflated 73%)
#   adding: content/sd/stable-diffusion-webui/modules/extras.py (deflated 72%)
#   adding: content/sd/stable-diffusion-webui/modules/memmon.py (deflated 70%)
#   adding: content/sd/stable-diffusion-webui/modules/extra_networks.py (deflated 72%)
#   adding: content/sd/stable-diffusion-webui/modules/paths_internal.py (deflated 57%)
#   adding: content/sd/stable-diffusion-webui/modules/interrogate.py (deflated 71%)
#   adding: content/sd/stable-diffusion-webui/modules/ui.py (deflated 80%)
#   adding: content/sd/stable-diffusion-webui/modules/masking.py (deflated 68%)
#   adding: content/sd/stable-diffusion-webui/modules/esrgan_model.py (deflated 75%)
#   adding: content/sd/stable-diffusion-webui/modules/safe.py (deflated 70%)
#   adding: content/sd/stable-diffusion-webui/modules/deepbooru.py (deflated 63%)
#   adding: content/sd/stable-diffusion-webui/modules/ui_common.py (deflated 71%)
#   adding: content/sd/stable-diffusion-webui/modules/shared.py (deflated 72%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_samplers_kdiffusion.py (deflated 76%)
#   adding: content/sd/stable-diffusion-webui/modules/devices.py (deflated 67%)
#   adding: content/sd/stable-diffusion-webui/modules/models/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/modules/models/diffusion/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/modules/models/diffusion/ddpm_edit.py (deflated 78%)
#   adding: content/sd/stable-diffusion-webui/modules/models/diffusion/uni_pc/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/modules/models/diffusion/uni_pc/__init__.py (deflated 6%)
#   adding: content/sd/stable-diffusion-webui/modules/models/diffusion/uni_pc/sampler.py (deflated 68%)
#   adding: content/sd/stable-diffusion-webui/modules/models/diffusion/uni_pc/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/modules/models/diffusion/uni_pc/__pycache__/uni_pc.cpython-39.pyc (deflated 59%)
#   adding: content/sd/stable-diffusion-webui/modules/models/diffusion/uni_pc/__pycache__/sampler.cpython-39.pyc (deflated 42%)
#   adding: content/sd/stable-diffusion-webui/modules/models/diffusion/uni_pc/__pycache__/__init__.cpython-39.pyc (deflated 22%)
#   adding: content/sd/stable-diffusion-webui/modules/models/diffusion/uni_pc/uni_pc.py (deflated 77%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_hijack_clip.py (deflated 70%)
#   adding: content/sd/stable-diffusion-webui/modules/paths.py (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/modules/ngrok.py (deflated 56%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/preprocess.py (deflated 75%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/ui.py (deflated 65%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/dataset.py (deflated 71%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/__pycache__/ui.cpython-39.pyc (deflated 41%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/__pycache__/image_embedding.cpython-39.pyc (deflated 46%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/__pycache__/preprocess.cpython-39.pyc (deflated 44%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/__pycache__/learn_schedule.cpython-39.pyc (deflated 49%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/__pycache__/autocrop.cpython-39.pyc (deflated 49%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/__pycache__/logging.cpython-39.pyc (deflated 38%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/__pycache__/dataset.cpython-39.pyc (deflated 50%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/__pycache__/textual_inversion.cpython-39.pyc (deflated 49%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/textual_inversion.py (deflated 76%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/logging.py (deflated 57%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/image_embedding.py (deflated 69%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/test_embedding.png (deflated 22%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/autocrop.py (deflated 71%)
#   adding: content/sd/stable-diffusion-webui/modules/textual_inversion/learn_schedule.py (deflated 72%)
#   adding: content/sd/stable-diffusion-webui/modules/styles.py (deflated 65%)
#   adding: content/sd/stable-diffusion-webui/modules/scripts_postprocessing.py (deflated 69%)
#   adding: content/sd/stable-diffusion-webui/modules/deepbooru_model.py (deflated 87%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_hijack_checkpoint.py (deflated 75%)
#   adding: content/sd/stable-diffusion-webui/modules/api/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/modules/api/api.py (deflated 77%)
#   adding: content/sd/stable-diffusion-webui/modules/api/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/modules/api/__pycache__/api.cpython-39.pyc (deflated 56%)
#   adding: content/sd/stable-diffusion-webui/modules/api/__pycache__/models.cpython-39.pyc (deflated 60%)
#   adding: content/sd/stable-diffusion-webui/modules/api/models.py (deflated 74%)
#   adding: content/sd/stable-diffusion-webui/modules/script_callbacks.py (deflated 79%)
#   adding: content/sd/stable-diffusion-webui/modules/postprocessing.py (deflated 69%)
#   adding: content/sd/stable-diffusion-webui/modules/ui_extra_networks.py (deflated 69%)
#   adding: content/sd/stable-diffusion-webui/modules/codeformer_model.py (deflated 69%)
#   adding: content/sd/stable-diffusion-webui/modules/errors.py (deflated 52%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_vae.cpython-39.pyc (deflated 47%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/ui_components.cpython-39.pyc (deflated 64%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/shared.cpython-39.pyc (deflated 56%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/esrgan_model_arch.cpython-39.pyc (deflated 53%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_hijack_optimizations.cpython-39.pyc (deflated 55%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/deepbooru_model.cpython-39.pyc (deflated 65%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/ui_extensions.cpython-39.pyc (deflated 52%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_vae_approx.cpython-39.pyc (deflated 39%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/ui_common.cpython-39.pyc (deflated 44%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/hashes.cpython-39.pyc (deflated 43%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_hijack_inpainting.cpython-39.pyc (deflated 44%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/deepbooru.cpython-39.pyc (deflated 44%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/images.cpython-39.pyc (deflated 52%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/ui.cpython-39.pyc (deflated 57%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_samplers_common.cpython-39.pyc (deflated 41%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_hijack_xlmr.cpython-39.pyc (deflated 44%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/extensions.cpython-39.pyc (deflated 45%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/shared_items.cpython-39.pyc (deflated 49%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/paths.cpython-39.pyc (deflated 43%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/img2img.cpython-39.pyc (deflated 42%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_hijack_checkpoint.cpython-39.pyc (deflated 51%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/interrogate.cpython-39.pyc (deflated 49%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/prompt_parser.cpython-39.pyc (deflated 57%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/timer.cpython-39.pyc (deflated 46%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/ui_extra_networks_checkpoints.cpython-39.pyc (deflated 48%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/scripts_auto_postprocessing.cpython-39.pyc (deflated 52%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_samplers_compvis.cpython-39.pyc (deflated 52%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_samplers_kdiffusion.cpython-39.pyc (deflated 53%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/realesrgan_model.cpython-39.pyc (deflated 54%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/paths_internal.cpython-39.pyc (deflated 38%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/gfpgan_model.cpython-39.pyc (deflated 48%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/errors.cpython-39.pyc (deflated 40%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_hijack.cpython-39.pyc (deflated 55%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_hijack_clip.cpython-39.pyc (deflated 54%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/ui_extra_networks_textual_inversion.cpython-39.pyc (deflated 48%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_hijack_utils.cpython-39.pyc (deflated 43%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/devices.cpython-39.pyc (deflated 50%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/cmd_args.cpython-39.pyc (deflated 59%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/styles.cpython-39.pyc (deflated 55%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/generation_parameters_copypaste.cpython-39.pyc (deflated 47%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/scripts_postprocessing.cpython-39.pyc (deflated 54%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/progress.cpython-39.pyc (deflated 44%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/txt2img.cpython-39.pyc (deflated 44%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/extra_networks_hypernet.cpython-39.pyc (deflated 46%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_models_config.cpython-39.pyc (deflated 46%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/ui_postprocessing.cpython-39.pyc (deflated 46%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/scripts.cpython-39.pyc (deflated 61%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/extra_networks.cpython-39.pyc (deflated 54%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_disable_initialization.cpython-39.pyc (deflated 57%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/ui_tempdir.cpython-39.pyc (deflated 41%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/import_hook.cpython-39.pyc (deflated 19%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/esrgan_model.cpython-39.pyc (deflated 46%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/call_queue.cpython-39.pyc (deflated 40%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/postprocessing.cpython-39.pyc (deflated 40%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/xlmr.cpython-39.pyc (deflated 49%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/script_callbacks.cpython-39.pyc (deflated 68%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/processing.cpython-39.pyc (deflated 51%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/face_restoration.cpython-39.pyc (deflated 46%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/ui_extra_networks_hypernets.cpython-39.pyc (deflated 48%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_hijack_unet.cpython-39.pyc (deflated 54%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/ui_extra_networks.cpython-39.pyc (deflated 51%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_hijack_open_clip.cpython-39.pyc (deflated 51%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/localization.cpython-39.pyc (deflated 36%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/extras.cpython-39.pyc (deflated 48%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sub_quadratic_attention.cpython-39.pyc (deflated 52%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/memmon.cpython-39.pyc (deflated 48%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/upscaler.cpython-39.pyc (deflated 56%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/safe.cpython-39.pyc (deflated 49%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/modelloader.cpython-39.pyc (deflated 45%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_models.cpython-39.pyc (deflated 49%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/masking.cpython-39.pyc (deflated 44%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/codeformer_model.cpython-39.pyc (deflated 44%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/script_loading.cpython-39.pyc (deflated 36%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/sd_samplers.cpython-39.pyc (deflated 44%)
#   adding: content/sd/stable-diffusion-webui/modules/__pycache__/lowvram.cpython-39.pyc (deflated 49%)
#   adding: content/sd/stable-diffusion-webui/modules/ui_extensions.py (deflated 75%)
#   adding: content/sd/stable-diffusion-webui/modules/timer.py (deflated 65%)
#   adding: content/sd/stable-diffusion-webui/modules/ui_components.py (deflated 73%)
#   adding: content/sd/stable-diffusion-webui/modules/scripts_auto_postprocessing.py (deflated 63%)
#   adding: content/sd/stable-diffusion-webui/modules/img2img.py (deflated 69%)
#   adding: content/sd/stable-diffusion-webui/modules/lowvram.py (deflated 75%)
#   adding: content/sd/stable-diffusion-webui/modules/realesrgan_model.py (deflated 77%)
#   adding: content/sd/stable-diffusion-webui/modules/hashes.py (deflated 68%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_models.py (deflated 73%)
#   adding: content/sd/stable-diffusion-webui/modules/hypernetworks/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/modules/hypernetworks/ui.py (deflated 60%)
#   adding: content/sd/stable-diffusion-webui/modules/hypernetworks/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/modules/hypernetworks/__pycache__/ui.cpython-39.pyc (deflated 41%)
#   adding: content/sd/stable-diffusion-webui/modules/hypernetworks/__pycache__/hypernetwork.cpython-39.pyc (deflated 50%)
#   adding: content/sd/stable-diffusion-webui/modules/hypernetworks/hypernetwork.py (deflated 77%)
#   adding: content/sd/stable-diffusion-webui/modules/ui_extra_networks_textual_inversion.py (deflated 61%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_samplers_compvis.py (deflated 75%)
#   adding: content/sd/stable-diffusion-webui/modules/mac_specific.py (deflated 70%)
#   adding: content/sd/stable-diffusion-webui/modules/localization.py (deflated 59%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_hijack_inpainting.py (deflated 70%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_vae_approx.py (deflated 63%)
#   adding: content/sd/stable-diffusion-webui/modules/shared_items.py (deflated 60%)
#   adding: content/sd/stable-diffusion-webui/modules/processing.py (deflated 77%)
#   adding: content/sd/stable-diffusion-webui/modules/extensions.py (deflated 68%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_hijack_utils.py (deflated 70%)
#   adding: content/sd/stable-diffusion-webui/modules/xlmr.py (deflated 74%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_disable_initialization.py (deflated 74%)
#   adding: content/sd/stable-diffusion-webui/modules/import_hook.py (deflated 27%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_hijack_open_clip.py (deflated 58%)
#   adding: content/sd/stable-diffusion-webui/modules/ui_extra_networks_checkpoints.py (deflated 59%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_hijack_unet.py (deflated 69%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_vae.py (deflated 73%)
#   adding: content/sd/stable-diffusion-webui/modules/esrgan_model_arch.py (deflated 76%)
#   adding: content/sd/stable-diffusion-webui/modules/codeformer/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/modules/codeformer/codeformer_arch.py (deflated 69%)
#   adding: content/sd/stable-diffusion-webui/modules/codeformer/vqgan_arch.py (deflated 77%)
#   adding: content/sd/stable-diffusion-webui/modules/codeformer/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/modules/codeformer/__pycache__/codeformer_arch.cpython-39.pyc (deflated 47%)
#   adding: content/sd/stable-diffusion-webui/modules/codeformer/__pycache__/vqgan_arch.cpython-39.pyc (deflated 54%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_hijack_optimizations.py (deflated 78%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_models_config.py (deflated 70%)
#   adding: content/sd/stable-diffusion-webui/modules/txt2img.py (deflated 69%)
#   adding: content/sd/stable-diffusion-webui/modules/ui_postprocessing.py (deflated 67%)
#   adding: content/sd/stable-diffusion-webui/modules/modelloader.py (deflated 70%)
#   adding: content/sd/stable-diffusion-webui/modules/face_restoration.py (deflated 58%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_hijack_clip_old.py (deflated 71%)
#   adding: content/sd/stable-diffusion-webui/modules/prompt_parser.py (deflated 70%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_hijack_ip2p.py (deflated 53%)
#   adding: content/sd/stable-diffusion-webui/modules/sd_hijack_xlmr.py (deflated 55%)
#   adding: content/sd/stable-diffusion-webui/modules/images.py (deflated 72%)
#   adding: content/sd/stable-diffusion-webui/modules/cmd_args.py (deflated 75%)
#   adding: content/sd/stable-diffusion-webui/requirements.txt (deflated 32%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/prompt-bracket-checker/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/prompt-bracket-checker/javascript/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/prompt-bracket-checker/javascript/prompt-bracket-checker.js (deflated 74%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/LDSR/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/LDSR/ldsr_model_arch.py (deflated 70%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/LDSR/scripts/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/LDSR/scripts/ldsr_model.py (deflated 64%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/LDSR/scripts/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/LDSR/scripts/__pycache__/ldsr_model.cpython-39.pyc (deflated 42%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/LDSR/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/LDSR/__pycache__/sd_hijack_ddpm_v1.cpython-39.pyc (deflated 55%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/LDSR/__pycache__/preload.cpython-39.pyc (deflated 29%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/LDSR/__pycache__/sd_hijack_autoencoder.cpython-39.pyc (deflated 49%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/LDSR/__pycache__/ldsr_model_arch.cpython-39.pyc (deflated 41%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/LDSR/sd_hijack_ddpm_v1.py (deflated 79%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/LDSR/preload.py (deflated 25%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/LDSR/sd_hijack_autoencoder.py (deflated 74%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/Lora/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/Lora/lora.py (deflated 75%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/Lora/ui_extra_networks_lora.py (deflated 60%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/Lora/scripts/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/Lora/scripts/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/Lora/scripts/__pycache__/lora_script.cpython-39.pyc (deflated 52%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/Lora/scripts/lora_script.py (deflated 77%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/Lora/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/Lora/__pycache__/preload.cpython-39.pyc (deflated 29%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/Lora/__pycache__/ui_extra_networks_lora.cpython-39.pyc (deflated 45%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/Lora/__pycache__/extra_networks_lora.cpython-39.pyc (deflated 43%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/Lora/__pycache__/lora.cpython-39.pyc (deflated 53%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/Lora/preload.py (deflated 25%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/Lora/extra_networks_lora.py (deflated 60%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/SwinIR/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/SwinIR/scripts/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/SwinIR/scripts/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/SwinIR/scripts/__pycache__/swinir_model.cpython-39.pyc (deflated 42%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/SwinIR/scripts/swinir_model.py (deflated 67%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/SwinIR/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/SwinIR/__pycache__/preload.cpython-39.pyc (deflated 30%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/SwinIR/__pycache__/swinir_model_arch_v2.cpython-39.pyc (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/SwinIR/__pycache__/swinir_model_arch.cpython-39.pyc (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/SwinIR/preload.py (deflated 27%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/SwinIR/swinir_model_arch.py (deflated 80%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/SwinIR/swinir_model_arch_v2.py (deflated 82%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/ScuNET/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/ScuNET/scripts/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/ScuNET/scripts/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/ScuNET/scripts/__pycache__/scunet_model.cpython-39.pyc (deflated 40%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/ScuNET/scripts/scunet_model.py (deflated 65%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/ScuNET/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/ScuNET/__pycache__/preload.cpython-39.pyc (deflated 30%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/ScuNET/__pycache__/scunet_model_arch.cpython-39.pyc (deflated 54%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/ScuNET/scunet_model_arch.py (deflated 76%)
#   adding: content/sd/stable-diffusion-webui/extensions-builtin/ScuNET/preload.py (deflated 26%)
#   adding: content/sd/stable-diffusion-webui/ui-config.json (deflated 87%)
#   adding: content/sd/stable-diffusion-webui/cache.json (deflated 33%)
#   adding: content/sd/stable-diffusion-webui/webui.bat (deflated 65%)
#   adding: content/sd/stable-diffusion-webui/textual_inversion_templates/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/textual_inversion_templates/subject.txt (deflated 76%)
#   adding: content/sd/stable-diffusion-webui/textual_inversion_templates/none.txt (stored 0%)
#   adding: content/sd/stable-diffusion-webui/textual_inversion_templates/style.txt (deflated 78%)
#   adding: content/sd/stable-diffusion-webui/textual_inversion_templates/subject_filewords.txt (deflated 83%)
#   adding: content/sd/stable-diffusion-webui/textual_inversion_templates/style_filewords.txt (deflated 84%)
#   adding: content/sd/stable-diffusion-webui/textual_inversion_templates/hypernetwork.txt (deflated 79%)
#   adding: content/sd/stable-diffusion-webui/webui-user.sh (deflated 53%)
#   adding: content/sd/stable-diffusion-webui/.github/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.github/workflows/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.github/workflows/run_tests.yaml (deflated 52%)
#   adding: content/sd/stable-diffusion-webui/.github/workflows/on_pull_request.yaml (deflated 51%)
#   adding: content/sd/stable-diffusion-webui/.github/pull_request_template.md (deflated 47%)
#   adding: content/sd/stable-diffusion-webui/.github/ISSUE_TEMPLATE/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.github/ISSUE_TEMPLATE/config.yml (deflated 20%)
#   adding: content/sd/stable-diffusion-webui/.github/ISSUE_TEMPLATE/bug_report.yml (deflated 64%)
#   adding: content/sd/stable-diffusion-webui/.github/ISSUE_TEMPLATE/feature_request.yml (deflated 59%)
#   adding: content/sd/stable-diffusion-webui/extensions/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/requirements.txt (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/install.py (deflated 41%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/extract_controlnet_diff.py (deflated 71%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/extract_controlnet.py (deflated 61%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/.github/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/.github/workflows/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/.github/workflows/tests.yml (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/.github/ISSUE_TEMPLATE/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/.github/ISSUE_TEMPLATE/config.yml (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/.github/ISSUE_TEMPLATE/bug_report.yml (deflated 63%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/LICENSE (deflated 40%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/models/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/models/image_adapter_v14.yaml (deflated 24%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/models/control_canny-fp16.safetensors (deflated 8%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/models/t2iadapter_style-fp16.yaml (deflated 24%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/models/t2iadapter_keypose-fp16.yaml (deflated 24%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/models/sketch_adapter_v14.yaml (deflated 24%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/models/cldm_v15.yaml (deflated 69%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/models/cldm_v21.yaml (deflated 69%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/models/t2iadapter_color-fp16.yaml (deflated 19%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/api.py (deflated 76%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/external_code.py (deflated 72%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/__pycache__/external_code.cpython-39.pyc (deflated 54%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/__pycache__/xyz_grid_support.cpython-39.pyc (deflated 56%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/__pycache__/api.cpython-39.pyc (deflated 52%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/__pycache__/processor.cpython-39.pyc (deflated 65%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/__pycache__/hook.cpython-39.pyc (deflated 47%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/__pycache__/adapter.cpython-39.pyc (deflated 56%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/__pycache__/global_state.cpython-39.pyc (deflated 44%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/__pycache__/cldm.cpython-39.pyc (deflated 47%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/__pycache__/utils.cpython-39.pyc (deflated 35%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/__pycache__/controlnet.cpython-39.pyc (deflated 52%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/__pycache__/movie2movie.cpython-39.pyc (deflated 43%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/hook.py (deflated 73%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/xyz_grid_support.py (deflated 77%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/global_state.py (deflated 66%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/adapter.py (deflated 75%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/movie2movie.py (deflated 67%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py (deflated 78%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/cldm.py (deflated 76%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/processor.py (deflated 82%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/utils.py (deflated 57%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/.gitignore (deflated 52%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/__pycache__/preload.cpython-39.pyc (deflated 34%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mlsd/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mlsd/__init__.py (deflated 61%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mlsd/models/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mlsd/models/mbv2_mlsd_tiny.py (deflated 71%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mlsd/models/mbv2_mlsd_large.py (deflated 72%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mlsd/utils.py (deflated 77%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/binary/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/binary/__init__.py (deflated 53%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/__init__.py (deflated 66%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/leres/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/leres/network_auxi.py (deflated 87%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/leres/Resnext_torch.py (deflated 73%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/leres/LICENSE (deflated 40%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/leres/multi_depth_model_woauxi.py (deflated 63%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/leres/Resnet.py (deflated 79%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/leres/net_tools.py (deflated 64%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/leres/depthmap.py (deflated 71%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/options/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/options/__init__.py (deflated 32%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/options/base_options.py (deflated 70%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/options/test_options.py (deflated 56%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/util/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/util/__init__.py (deflated 14%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/util/image_pool.py (deflated 67%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/util/util.py (deflated 64%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/util/visualizer.py (deflated 67%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/util/html.py (deflated 63%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/util/guidedfilter.py (deflated 67%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/util/get_data.py (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/LICENSE (deflated 41%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/models/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/models/__init__.py (deflated 60%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/models/base_model.py (deflated 70%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/models/pix2pix4depth_model.py (deflated 68%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/models/base_model_hg.py (deflated 67%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/leres/pix2pix/models/networks.py (deflated 77%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/__init__.py (deflated 67%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/upernet_global_small.py (deflated 58%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/mmcv_custom/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/mmcv_custom/__init__.py (deflated 23%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/mmcv_custom/checkpoint.py (deflated 74%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/inference.py (deflated 66%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/uniformer.py (deflated 79%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/schedules/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/schedules/schedule_20k.py (deflated 39%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/schedules/schedule_80k.py (deflated 39%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/schedules/schedule_160k.py (deflated 40%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/schedules/schedule_40k.py (deflated 39%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/ccnet_r50-d8.py (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/dnl_r50-d8.py (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/deeplabv3_r50-d8.py (deflated 63%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/encnet_r50-d8.py (deflated 64%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/nonlocal_r50-d8.py (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/pspnet_unet_s5-d16.py (deflated 66%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/upernet_r50.py (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/dmnet_r50-d8.py (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/pspnet_r50-d8.py (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/gcnet_r50-d8.py (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/fcn_unet_s5-d16.py (deflated 68%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/ann_r50-d8.py (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/upernet_uniformer.py (deflated 63%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/fast_scnn.py (deflated 72%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/fpn_r50.py (deflated 55%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/fcn_hr18.py (deflated 68%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/apcnet_r50-d8.py (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/fpn_uniformer.py (deflated 56%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/psanet_r50-d8.py (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/danet_r50-d8.py (deflated 63%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/deeplabv3plus_r50-d8.py (deflated 63%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/ocrnet_r50-d8.py (deflated 64%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/deeplabv3_unet_s5-d16.py (deflated 66%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/pointrend_r50.py (deflated 63%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/lraspp_m-v3-d8.py (deflated 50%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/emanet_r50-d8.py (deflated 63%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/cgnet.py (deflated 54%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/fcn_r50-d8.py (deflated 64%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/models/ocrnet_hr18.py (deflated 73%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/datasets/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/datasets/pascal_voc12_aug.py (deflated 43%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/datasets/hrf.py (deflated 67%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/datasets/pascal_voc12.py (deflated 67%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/datasets/pascal_context.py (deflated 68%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/datasets/cityscapes_769x769.py (deflated 60%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/datasets/ade20k.py (deflated 66%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/datasets/stare.py (deflated 67%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/datasets/pascal_context_59.py (deflated 67%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/datasets/drive.py (deflated 66%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/datasets/cityscapes.py (deflated 66%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/datasets/chase_db1.py (deflated 66%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer/configs/_base_/default_runtime.py (deflated 32%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/keypose/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/keypose/__init__.py (deflated 69%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/keypose/faster_rcnn_r50_fpn_coco.py (deflated 70%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/keypose/hrnet_w48_coco_256x192.py (deflated 71%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mmpkg/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mmpkg/mmseg/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mmpkg/mmseg/models/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mmpkg/mmseg/models/backbones/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mmpkg/mmseg/models/backbones/__init__.py (deflated 57%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mmpkg/mmseg/models/backbones/hrnet.py (deflated 82%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mmpkg/mmseg/models/backbones/mobilenet_v3.py (deflated 75%)
# ...
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/sk-b-src.png (deflated 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/kp_o-2.png (deflated 1%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/kp_o2-2.png (deflated 2%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/nm-src.png (deflated 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/evt_gen.png (deflated 2%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/cat_sk-2.png (deflated 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/dog_rel.jpg (deflated 1%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/an-pose.png (deflated 11%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/bal-gen.png (deflated 1%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/dog_sk-2.png (deflated 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/sk-b-dep.png (deflated 1%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/kp_a2-2.png (deflated 2%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/mahiro_canny.png (deflated 1%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/an-source.jpg (deflated 3%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/nm-out.png (deflated 1%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/nm-gen.png (deflated 3%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/bal-source.png (deflated 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/an-gen.png (deflated 1%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/dog_out-2.png (deflated 1%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/fs_output.png (deflated 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/fs_input.png (deflated 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/evt_source.jpg (deflated 1%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/kp_a-2.png (deflated 3%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/sk-b-out.png (deflated 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/evt_hed.png (deflated 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/cat_out-2.png (deflated 1%)
#   adding: content/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/samples/dog_rel.png (deflated 0%)
#   adding: content/sd/stable-diffusion-webui/extensions/put extensions here.txt (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.pylintrc (deflated 4%)
#   adding: content/sd/stable-diffusion-webui/models/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/models/GFPGAN/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/models/deepbooru/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/models/deepbooru/Put your deepbooru release project folder here.txt (stored 0%)
#   adding: content/sd/stable-diffusion-webui/models/LDSR/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/models/ESRGAN/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/models/VAE-approx/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/models/VAE-approx/model.pt (deflated 8%)
#   adding: content/sd/stable-diffusion-webui/models/Codeformer/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/models/VAE/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/models/VAE/Put VAE here.txt (stored 0%)
#   adding: content/sd/stable-diffusion-webui/models/hypernetworks/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/models/Stable-diffusion/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/models/Stable-diffusion/Put Stable Diffusion checkpoints here.txt (stored 0%)
#   adding: content/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt (deflated 8%)
#   adding: content/sd/stable-diffusion-webui/models/Lora/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/models/SwinIR/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/models/ControlNet/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/cache.json.lock (stored 0%)
#   adding: content/sd/stable-diffusion-webui/requirements_versions.txt (deflated 38%)
#   adding: content/sd/stable-diffusion-webui/webui.py (deflated 73%)
#   adding: content/sd/stable-diffusion-webui/javascript/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/javascript/dragdrop.js (deflated 68%)
#   adding: content/sd/stable-diffusion-webui/javascript/edit-attention.js (deflated 68%)
#   adding: content/sd/stable-diffusion-webui/javascript/aspectRatioOverlay.js (deflated 72%)
#   adding: content/sd/stable-diffusion-webui/javascript/hints.js (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/javascript/progressbar.js (deflated 69%)
#   adding: content/sd/stable-diffusion-webui/javascript/hires_fix.js (deflated 66%)
#   adding: content/sd/stable-diffusion-webui/javascript/extensions.js (deflated 66%)
#   adding: content/sd/stable-diffusion-webui/javascript/notification.js (deflated 55%)
#   adding: content/sd/stable-diffusion-webui/javascript/localization.js (deflated 67%)
#   adding: content/sd/stable-diffusion-webui/javascript/ui.js (deflated 72%)
#   adding: content/sd/stable-diffusion-webui/javascript/imageMaskFix.js (deflated 59%)
#   adding: content/sd/stable-diffusion-webui/javascript/contextMenus.js (deflated 73%)
#   adding: content/sd/stable-diffusion-webui/javascript/imageviewer.js (deflated 74%)
#   adding: content/sd/stable-diffusion-webui/javascript/extraNetworks.js (deflated 70%)
#   adding: content/sd/stable-diffusion-webui/javascript/imageParams.js (deflated 49%)
#   adding: content/sd/stable-diffusion-webui/javascript/textualInversion.js (deflated 46%)
#   adding: content/sd/stable-diffusion-webui/javascript/generationParams.js (deflated 58%)
#   adding: content/sd/stable-diffusion-webui/scripts/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/scripts/postprocessing_codeformer.py (deflated 67%)
#   adding: content/sd/stable-diffusion-webui/scripts/prompts_from_file.py (deflated 68%)
#   adding: content/sd/stable-diffusion-webui/scripts/prompt_matrix.py (deflated 68%)
#   adding: content/sd/stable-diffusion-webui/scripts/postprocessing_gfpgan.py (deflated 59%)
#   adding: content/sd/stable-diffusion-webui/scripts/outpainting_mk_2.py (deflated 73%)
#   adding: content/sd/stable-diffusion-webui/scripts/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/scripts/__pycache__/outpainting_mk_2.cpython-39.pyc (deflated 47%)
#   adding: content/sd/stable-diffusion-webui/scripts/__pycache__/xyz_grid.cpython-39.pyc (deflated 55%)
#   adding: content/sd/stable-diffusion-webui/scripts/__pycache__/postprocessing_upscale.cpython-39.pyc (deflated 56%)
#   adding: content/sd/stable-diffusion-webui/scripts/__pycache__/img2imgalt.cpython-39.pyc (deflated 49%)
#   adding: content/sd/stable-diffusion-webui/scripts/__pycache__/poor_mans_outpainting.cpython-39.pyc (deflated 44%)
#   adding: content/sd/stable-diffusion-webui/scripts/__pycache__/prompt_matrix.cpython-39.pyc (deflated 43%)
#   adding: content/sd/stable-diffusion-webui/scripts/__pycache__/prompts_from_file.cpython-39.pyc (deflated 46%)
#   adding: content/sd/stable-diffusion-webui/scripts/__pycache__/loopback.cpython-39.pyc (deflated 43%)
#   adding: content/sd/stable-diffusion-webui/scripts/__pycache__/postprocessing_codeformer.cpython-39.pyc (deflated 43%)
#   adding: content/sd/stable-diffusion-webui/scripts/__pycache__/postprocessing_gfpgan.cpython-39.pyc (deflated 39%)
#   adding: content/sd/stable-diffusion-webui/scripts/__pycache__/sd_upscale.cpython-39.pyc (deflated 41%)
#   adding: content/sd/stable-diffusion-webui/scripts/__pycache__/custom_code.cpython-39.pyc (deflated 42%)
#   adding: content/sd/stable-diffusion-webui/scripts/poor_mans_outpainting.py (deflated 72%)
#   adding: content/sd/stable-diffusion-webui/scripts/postprocessing_upscale.py (deflated 77%)
#   adding: content/sd/stable-diffusion-webui/scripts/sd_upscale.py (deflated 66%)
#   adding: content/sd/stable-diffusion-webui/scripts/loopback.py (deflated 73%)
#   adding: content/sd/stable-diffusion-webui/scripts/xyz_grid.py (deflated 77%)
#   adding: content/sd/stable-diffusion-webui/scripts/custom_code.py (deflated 60%)
#   adding: content/sd/stable-diffusion-webui/scripts/img2imgalt.py (deflated 76%)
#   adding: content/sd/stable-diffusion-webui/embeddings/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/embeddings/Place Textual Inversion embeddings here.txt (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.gitignore (deflated 39%)
#   adding: content/sd/stable-diffusion-webui/__pycache__/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/__pycache__/launch.cpython-39.pyc (deflated 48%)
#   adding: content/sd/stable-diffusion-webui/script.js (deflated 65%)
#   adding: content/sd/stable-diffusion-webui/CODEOWNERS (deflated 42%)
#   adding: content/sd/stable-diffusion-webui/cache/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/cache/huggingface/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/test/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/test/__init__.py (stored 0%)
#   adding: content/sd/stable-diffusion-webui/test/test_files/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/test/test_files/img2img_basic.png (stored 0%)
#   adding: content/sd/stable-diffusion-webui/test/test_files/mask_basic.png (deflated 3%)
#   adding: content/sd/stable-diffusion-webui/test/test_files/empty.pt (deflated 63%)
#   adding: content/sd/stable-diffusion-webui/test/basic_features/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/test/basic_features/__init__.py (stored 0%)
#   adding: content/sd/stable-diffusion-webui/test/basic_features/extras_test.py (deflated 72%)
#   adding: content/sd/stable-diffusion-webui/test/basic_features/utils_test.py (deflated 79%)
#   adding: content/sd/stable-diffusion-webui/test/basic_features/img2img_test.py (deflated 71%)
#   adding: content/sd/stable-diffusion-webui/test/basic_features/txt2img_test.py (deflated 80%)
#   adding: content/sd/stable-diffusion-webui/test/server_poll.py (deflated 53%)
#   adding: content/sd/stable-diffusion-webui/LICENSE.txt (deflated 66%)
#   adding: content/sd/stable-diffusion-webui/webui-macos-env.sh (deflated 50%)
#   adding: content/sd/stable-diffusion-webui/.git/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/hooks/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/hooks/fsmonitor-watchman.sample (deflated 52%)
#   adding: content/sd/stable-diffusion-webui/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: content/sd/stable-diffusion-webui/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: content/sd/stable-diffusion-webui/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/sd/stable-diffusion-webui/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/sd/stable-diffusion-webui/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/sd/stable-diffusion-webui/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/sd/stable-diffusion-webui/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/sd/stable-diffusion-webui/.git/hooks/update.sample (deflated 68%)
#   adding: content/sd/stable-diffusion-webui/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/sd/stable-diffusion-webui/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/sd/stable-diffusion-webui/.git/hooks/pre-push.sample (deflated 50%)
#   adding: content/sd/stable-diffusion-webui/.git/config (deflated 32%)
#   adding: content/sd/stable-diffusion-webui/.git/objects/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/objects/pack/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/objects/pack/pack-444f619066cfd02176439224cd187d563238a1b7.idx (deflated 10%)
#   adding: content/sd/stable-diffusion-webui/.git/objects/pack/pack-444f619066cfd02176439224cd187d563238a1b7.pack (deflated 0%)
#   adding: content/sd/stable-diffusion-webui/.git/objects/info/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/logs/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/logs/HEAD (deflated 51%)
#   adding: content/sd/stable-diffusion-webui/.git/logs/refs/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/logs/refs/heads/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/logs/refs/heads/master (deflated 26%)
#   adding: content/sd/stable-diffusion-webui/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/logs/refs/remotes/origin/HEAD (deflated 26%)
#   adding: content/sd/stable-diffusion-webui/.git/index (deflated 56%)
#   adding: content/sd/stable-diffusion-webui/.git/FETCH_HEAD (deflated 4%)
#   adding: content/sd/stable-diffusion-webui/.git/packed-refs (deflated 11%)
#   adding: content/sd/stable-diffusion-webui/.git/HEAD (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/description (deflated 14%)
#   adding: content/sd/stable-diffusion-webui/.git/info/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/info/exclude (deflated 28%)
#   adding: content/sd/stable-diffusion-webui/.git/ORIG_HEAD (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/shallow (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/refs/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/refs/heads/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/refs/heads/master (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/refs/remotes/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/refs/tags/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/.git/branches/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/launch.py (deflated 69%)
#   adding: content/sd/stable-diffusion-webui/environment-wsl2.yaml (deflated 32%)
#   adding: content/sd/stable-diffusion-webui/configs/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/configs/instruct-pix2pix.yaml (deflated 59%)
#   adding: content/sd/stable-diffusion-webui/configs/alt-diffusion-inference.yaml (deflated 59%)
#   adding: content/sd/stable-diffusion-webui/configs/v1-inference.yaml (deflated 60%)
#   adding: content/sd/stable-diffusion-webui/configs/v1-inpainting-inference.yaml (deflated 58%)
#   adding: content/sd/stable-diffusion-webui/screenshot.png (deflated 3%)
#   adding: content/sd/stable-diffusion-webui/html/ (stored 0%)
#   adding: content/sd/stable-diffusion-webui/html/extra-networks-card.html (deflated 48%)
#   adding: content/sd/stable-diffusion-webui/html/card-no-preview.png (deflated 1%)
#   adding: content/sd/stable-diffusion-webui/html/extra-networks-no-cards.html (deflated 11%)
#   adding: content/sd/stable-diffusion-webui/html/image-update.svg (deflated 49%)
#   adding: content/sd/stable-diffusion-webui/html/footer.html (deflated 42%)
#   adding: content/sd/stable-diffusion-webui/html/licenses.html (deflated 82%)
#   adding: content/sd/stable-diffusion-webui/style.css (deflated 77%)
#   adding: content/sd/stable-diffusion-webui/webui-user.bat (deflated 12%)
#   adding: content/sd/stable-diffusion-webui/README.md (deflated 62%)
#   adding: content/sd/stable-diffusion-webui/detected_maps/ (stored 0%)

# %%
# !pwd
# Out:
# /content/sd/stable-diffusion-webui

# %%
from google.colab import files
files.download('sd.zip')
